# %% [markdown]
# <h1>Data Preparation</h1>

# %% [markdown]
# <h3>Importing needed Libraries</h3>

# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <h3>Importing all the Data Files</h3>

# %%
data_folder = '.\\CW_Data'

data_list = os.listdir(data_folder)
data_list
# Out:
# ['Sales_April_2019.csv',
#  'Sales_August_2019.csv',
#  'Sales_December_2019.csv',
#  'Sales_February_2019.csv',
#  'Sales_January_2019.csv',
#  'Sales_July_2019.csv',
#  'Sales_June_2019.csv',
#  'Sales_March_2019.csv',
#  'Sales_May_2019.csv',
#  'Sales_November_2019.csv',
#  'Sales_October_2019.csv',
#  'Sales_September_2019.csv']

# %% [markdown]
# <h3> Combining all the Data Files into a DataFrame </h3>

# %%
combined_data = []

for each in data_list:
    if each.endswith(".csv"):
        df = pd.read_csv(os.path.join(data_folder, each))
        combined_data.append(df)
        
combined_df = pd.concat(combined_data)
combined_df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0      176558.0        USB-C Charging Cable               2.0       11.95
# 1           NaN                         NaN               NaN         NaN
# 2      176559.0  Bose SoundSport Headphones               1.0       99.99
# 3      176560.0                Google Phone               1.0      600.00
# 4      176560.0            Wired Headphones               1.0       11.99
# ...         ...                         ...               ...         ...
# 11681  259353.0      AAA Batteries (4-pack)               3.0        2.99
# 11682  259354.0                      iPhone               1.0      700.00
# 11683  259355.0                      iPhone               1.0      700.00
# 11684  259356.0      34in Ultrawide Monitor               1.0      379.99
# 11685  259357.0        USB-C Charging Cable               1.0       11.95
#
#             Order Date                         Purchase Address
# ...

# %% [markdown]
# <h3> Removing all the NaN values </h3>

# %%
combined_df = combined_df.dropna()
combined_df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0      176558.0        USB-C Charging Cable               2.0       11.95
# 2      176559.0  Bose SoundSport Headphones               1.0       99.99
# 3      176560.0                Google Phone               1.0      600.00
# 4      176560.0            Wired Headphones               1.0       11.99
# 5      176561.0            Wired Headphones               1.0       11.99
# ...         ...                         ...               ...         ...
# 11681  259353.0      AAA Batteries (4-pack)               3.0        2.99
# 11682  259354.0                      iPhone               1.0      700.00
# 11683  259355.0                      iPhone               1.0      700.00
# 11684  259356.0      34in Ultrawide Monitor               1.0      379.99
# 11685  259357.0        USB-C Charging Cable               1.0       11.95
#
#             Order Date                         Purchase Address
# ...

# %% [markdown]
# <h3> Converting Datatypes of Columns </h3>

# %%
combined_df[['Quantity Ordered','Price Each']].apply(pd.to_numeric)
combined_df.dtypes
# Out:
# Order ID            float64
# Product              object
# Quantity Ordered    float64
# Price Each          float64
# Order Date           object
# Purchase Address     object
# dtype: object

# %% [markdown]
# <h3> Creating new Column "Month" from "Order Date" </h3>

# %%
combined_df['Order Date'] = pd.to_datetime(combined_df['Order Date'])
combined_df['Month'] = combined_df['Order Date'].dt.month
combined_df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0      176558.0        USB-C Charging Cable               2.0       11.95
# 2      176559.0  Bose SoundSport Headphones               1.0       99.99
# 3      176560.0                Google Phone               1.0      600.00
# 4      176560.0            Wired Headphones               1.0       11.99
# 5      176561.0            Wired Headphones               1.0       11.99
# ...         ...                         ...               ...         ...
# 11681  259353.0      AAA Batteries (4-pack)               3.0        2.99
# 11682  259354.0                      iPhone               1.0      700.00
# 11683  259355.0                      iPhone               1.0      700.00
# 11684  259356.0      34in Ultrawide Monitor               1.0      379.99
# 11685  259357.0        USB-C Charging Cable               1.0       11.95
#
#                Order Date                         Purchase Address  Month
# ...

# %% [markdown]
# <h3>Creating new Column "City" from "Purchase Address"</h3>

# %%
combined_df['City']  = [i.split(",")[1] for i in combined_df['Purchase Address'].values]
combined_df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0      176558.0        USB-C Charging Cable               2.0       11.95
# 2      176559.0  Bose SoundSport Headphones               1.0       99.99
# 3      176560.0                Google Phone               1.0      600.00
# 4      176560.0            Wired Headphones               1.0       11.99
# 5      176561.0            Wired Headphones               1.0       11.99
# ...         ...                         ...               ...         ...
# 11681  259353.0      AAA Batteries (4-pack)               3.0        2.99
# 11682  259354.0                      iPhone               1.0      700.00
# 11683  259355.0                      iPhone               1.0      700.00
# 11684  259356.0      34in Ultrawide Monitor               1.0      379.99
# 11685  259357.0        USB-C Charging Cable               1.0       11.95
#
#                Order Date                         Purchase Address  Month  \
# ...

# %% [markdown]
# <h1>Data Analysis</h1>

# %% [markdown]
# <h3> Sum of total sales made in each Month </h3>

# %%
combined_df['Total Price'] = combined_df['Price Each']*combined_df['Quantity Ordered']
Monthly = combined_df[['Month','Total Price']]
Monthly_sales = Monthly.groupby('Month')['Total Price'].sum()
Monthly_sales_df = pd.DataFrame(Monthly_sales)
Monthly_sales_df
# Out:
#        Total Price
# Month
# 1       1822256.73
# 2       2202022.42
# 3       2807100.38
# 4       3390670.24
# 5       3152606.75
# 6       2577802.26
# 7       2647775.76
# 8       2244467.88
# 9       2097560.13
# 10      3736726.88
# 11      3199603.20
# 12      4613443.34

# %% [markdown]
# <h3> Mean of Total Sales made in Each City </h3>

# %%
City_orders = combined_df[['City','Total Price']]
City_orders = City_orders.groupby('City')['Total Price'].mean()
Total_city_Orders = pd.DataFrame(City_orders)
Total_city_Orders
# Out:
#                 Total Price
# City
#  Atlanta         187.856903
#  Austin          183.703357
#  Boston          183.688272
#  Dallas          186.772969
#  Los Angeles     184.177362
#  New York City   187.502711
#  Portland        186.160498
#  San Francisco   184.704550
#  Seattle         186.516120

# %% [markdown]
# <h3> Standard Deviation </h3>

# %%
SD = combined_df[['Quantity Ordered','Total Price']].std()
SD = pd.DataFrame(SD)
SD
# Out:
#                            0
# Quantity Ordered    0.442793
# Total Price       332.919771

# %% [markdown]
# <h3> Skewness </h3>

# %%
SK = combined_df[['Quantity Ordered','Price Each']].skew()
SK = pd.DataFrame(SK)
SK
# Out:
#                          0
# Quantity Ordered  4.833164
# Price Each        2.872149

# %% [markdown]
# <h3> Kurtosis </h3>

# %%
KS = combined_df[['Quantity Ordered','Total Price']].kurtosis()
KS = pd.DataFrame(KS)
KS
# Out:
#                           0
# Quantity Ordered  31.820489
# Total Price        9.227075

# %% [markdown]
# <h3> Finding Correlation Between Columns </h3>

# %%
matrix = combined_df.corr()
sns.heatmap(matrix)
plt.show()

# %% [markdown]
# <h1>Data Exploration</h1>

# %% [markdown]
# <h3>Month that made Most Sales</h3>

# %%
Monthly = combined_df[['Month','Total Price']]
Monthly_sales = Monthly.groupby('Month')['Total Price'].sum()
Monthly_sales_df = pd.DataFrame(Monthly_sales)
Monthly_sales_df
# Out:
#        Total Price
# Month
# 1       1822256.73
# 2       2202022.42
# 3       2807100.38
# 4       3390670.24
# 5       3152606.75
# 6       2577802.26
# 7       2647775.76
# 8       2244467.88
# 9       2097560.13
# 10      3736726.88
# 11      3199603.20
# 12      4613443.34

# %%
Monthly_sales.plot.bar(x='Month', y='Total Price', title='Total Sales of Each Month')
plt.show()

# %% [markdown]
# <h3> City that made the most Sales </h3>

# %%
City_orders = combined_df[['City','Quantity Ordered']]
City_orders = City_orders.groupby('City')['Quantity Ordered'].sum()
Total_city_Orders = pd.DataFrame(City_orders)
Total_city_Orders
# Out:
#                 Quantity Ordered
# City
#  Atlanta                 16602.0
#  Austin                  11153.0
#  Boston                  22528.0
#  Dallas                  16730.0
#  Los Angeles             33289.0
#  New York City           27932.0
#  Portland                14053.0
#  San Francisco           50239.0
#  Seattle                 16553.0

# %%
Total_city_Orders.idxmax().max()
# Out:
# ' San Francisco'

# %% [markdown]
# <h3> Most sold Products </h3>

# %%
Products = combined_df[['Product','Quantity Ordered']]
Total_Products = Products.groupby('Product')['Quantity Ordered'].sum()
Total_Products_df = pd.DataFrame(Total_Products)
Total_Products_df
# Out:
#                             Quantity Ordered
# Product
# 20in Monitor                          4129.0
# 27in 4K Gaming Monitor                6244.0
# 27in FHD Monitor                      7550.0
# 34in Ultrawide Monitor                6199.0
# AA Batteries (4-pack)                27635.0
# AAA Batteries (4-pack)               31017.0
# Apple Airpods Headphones             15661.0
# Bose SoundSport Headphones           13457.0
# Flatscreen TV                         4819.0
# Google Phone                          5532.0
# LG Dryer                               646.0
# LG Washing Machine                     666.0
# Lightning Charging Cable             23217.0
# Macbook Pro Laptop                    4728.0
# ThinkPad Laptop                       4130.0
# USB-C Charging Cable                 23975.0
# Vareebadd Phone                       2068.0
# Wired Headphones                     20557.0
# iPhone                                6849.0

# %%
Total_Products_df.idxmax().max()
# Out:
# 'AAA Batteries (4-pack)'

# %%
Total_Products.plot.bar(x='Product',y='Quantity Ordered',title='Total sales of each item ordered')
plt.show()

# %% [markdown]
# <h3>Histogram</h3>

# %%
plt.hist(Total_city_Orders['Quantity Ordered'])
plt.show()
